# %%
#1
print('hellow , how are you')
# Out:
# hellow , how are you

# %%
#2
name = input('enter your name')
print('hello' + name+'glad to meet you!')
# Out:
# enter your namearifataj
# helloarifatajglad to meet you!

# %%
#3
num1 = int(input('enter a number'))
num2 = int(input('enter another number'))
print(num1+num2)
print(sum)
# Out:
# enter a number12
# enter another number13
# 25
# <built-in function sum>

# %%
#4
str  = input('enter a string')
print(str)
print(len(str))
# Out:
# enter a stringHappydays
# Happydays
# 9

# %%
#5
str = input('enter a string')
print(str.split())
print(len(str.split()))
# Out:
# enter a stringHow are you
# ['How', 'are', 'you']
# 3

# %%
#6

# %%
#7
str =input('enter a string')
print(str.upper())
# Out:
# enter a stringHey ABCD
# HEY ABCD

# %%
#8
str = input('enter a string :')
print(str.replace ('a' ,'e'))
# Out:
# enter a string :abianuafi
# ebienuefi

# %%
#9
str = input('enter a string')
if str == str[::-1]:
    print('palindrome')
else:
    print('not palindrome')
# Out:
# enter a stringHow are you
# not palindrome

# %%
#10
str = input('enter a string')
substr = input('enter a substring')
if substr in str:
    print('substring found')
else:
    print('substring not found')
# Out:
# enter a stringThe day is good
# enter a substringa good day
# substring not found

# %%
#12
sentence = int(input('enter the string'))
word = sentence.split()
print(word)
print('max word,key =len')
print(min word, key = len)
# Out:
#   File "<ipython-input-4-b6a38f767cf8>", line 6
#     print(min word, key = len)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
